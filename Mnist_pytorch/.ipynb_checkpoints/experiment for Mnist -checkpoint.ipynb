# %%
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.autograd import Variable
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image

# %%
pkl_file = open('two_numbers_dataset_6k.pkl', 'rb')
#a difficulty that confuse me a while here, the encode here is different from normal situation
raw_datasets = pickle.load(pkl_file, encoding = 'bytes')
img = []
label = []

batch_size = 50

# %%
raw_datasets[1][1]
# Out:
# [[9, 42, 26, 28, 28], [6, 17, 40, 28, 28]]

# %%
b = transforms.ToTensor()(raw_datasets[1][0].reshape(80, 80, 1))
torchvision.utils.save_image(b, 'test.jpg')
b = torch.squeeze(b)
c = b.numpy()
plt.imshow(c)
plt.show()

# %%
for i in range(len(raw_datasets)):
    img1 = transforms.ToTensor()(raw_datasets[i][0].reshape(80, 80, 1))
    img.append(img1)
    label.append([raw_datasets[i][1][0][0], raw_datasets[i][1][1][0]])
train_len = int(2 * len(raw_datasets)/3)
train_img = img[:train_len]
test_img = img[train_len:len(raw_datasets)]
tr_list_label = label[:train_len]
te_list_label = label[train_len:len(raw_datasets)]
train_label = []
test_label = []
for i in range(train_len):
    train_label.append(torch.from_numpy(np.array(tr_list_label[i])))
for i in range(len(raw_datasets) - train_len):
    test_label.append(torch.from_numpy(np.array(te_list_label[i])))

# %%
batch_img = []
batch_label = []
for i in range(int(train_len/batch_size)):
    batch_img.append(torch.stack(train_img[batch_size * i : batch_size * (i+1)], 0)) #in dim 0
    batch_label.append(torch.stack(train_label[batch_size * i : batch_size * (i+1)], 0))
for i in range(5):
    print(batch_img[i])
# Out:
# (0 ,0 ,.,.) =
#  -1.6929e-04  7.3457e-04  3.9776e-04  ...   3.4062e-04  4.5105e-04  2.2589e-05
#   7.2888e-04  8.1335e-04  4.8411e-06  ...  -8.2684e-05 -1.1572e-04  3.9609e-05
#   5.5934e-04 -2.0801e-04  5.7001e-04  ...   5.7957e-04  3.9370e-04  1.0183e-03
#                  ...                   ⋱                   ...
#   7.3416e-04  4.2321e-04  1.1798e-03  ...   2.7987e-04  3.6432e-04  3.0596e-04
#   5.2424e-04  4.5436e-04  3.9647e-04  ...   1.1143e-06  6.4016e-04  2.7968e-04
#   8.4396e-04  3.0643e-04  5.8238e-04  ...   4.5137e-04  5.8639e-04  8.1599e-04
#      ⋮
#
# (1 ,0 ,.,.) =
#   1.7477e-04  5.8287e-04  4.4780e-04  ...   4.6185e-04  1.2589e-05  1.7813e-04
#   1.1356e-03 -2.6010e-04  1.2098e-04  ...   2.0238e-04  3.6101e-04  5.2488e-04
#   2.7918e-04  9.7593e-04  5.3243e-04  ...   8.1543e-04 -5.6789e-05  9.5490e-06
#                  ...                   ⋱                   ...
#   3.9307e-04  1.7997e-04  7.6156e-04  ...   4.0948e-04  4.0135e-04 -4.9831e-04
#   7.9264e-04 -3.0593e-04  1.5788e-04  ...  -3.1334e-04  1.4324e-04  3.8278e-04
#   6.6811e-04  8.1906e-04  5.4131e-04  ...   7.5693e-04  3.0322e-04  1.0645e-03
#      ⋮
#
# (2 ,0 ,.,.) =
#   6.0466e-04 -3.6838e-04  2.9116e-04  ...   9.0185e-04  5.8950e-04  1.1115e-03
#   6.5931e-04  5.6948e-04  8.5657e-04  ...  -6.0437e-05  1.3935e-04 -8.3244e-05
#  -1.0850e-04  8.8389e-04  9.1517e-04  ...   4.6667e-04  7.1602e-04  1.2699e-03
#      ⋮
#
# (48,0 ,.,.) =
#   4.3107e-04  3.1944e-04 -4.0877e-04  ...   3.3395e-04 -2.2828e-04  2.7807e-04
#   2.0721e-05 -1.5317e-06  6.9376e-04  ...   5.6888e-05 -4.8677e-04  4.4120e-04
#   3.0014e-04  5.7814e-04  6.3546e-04  ...   2.4701e-04  3.1854e-04  4.0653e-04
#                  ...                   ⋱                   ...
#   6.0758e-05  9.1646e-04  8.9708e-04  ...   1.1184e-03  5.7556e-04 -9.0453e-05
#   4.4636e-04  8.0480e-04  1.0873e-03  ...   3.3869e-04  5.0134e-04  3.5914e-04
#   1.8699e-04 -1.1588e-05 -5.4817e-04  ...  -3.0421e-05  5.1833e-04  8.0152e-04
#      ⋮
#
# (49,0 ,.,.) =
#   9.1313e-04  6.7166e-04  7.1820e-04  ...   3.5479e-04  8.1513e-04  3.4926e-04
#   6.8028e-04  1.0179e-03  2.4898e-04  ...   1.1417e-04  4.4885e-04  6.5185e-05
#   1.2822e-03  9.5287e-04  7.1755e-05  ...   5.9177e-04  8.4310e-04  5.3661e-04
#                  ...                   ⋱                   ...
#   4.1940e-04  7.6919e-04  5.9635e-04  ...   2.3169e-04 -1.3368e-04  7.9012e-04
#   5.5571e-04  1.2693e-04  5.9711e-04  ...   7.3475e-04  2.7801e-04  7.1606e-04
#   8.6189e-04  1.2412e-03  8.5872e-04  ...   1.9108e-04  6.0880e-04  1.5826e-04
# [torch.FloatTensor of size 50x1x80x80]

# %%
class Minist_two_Module(nn.Module):
    def __init__(self):
        super(Minist_two_Module, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5, padding = 2)
        self.conv2 = nn.Conv2d(32, 64, 5, padding = 2)
        self.conv3 = nn.Conv2d(64, 128, 5, padding = 2)
        self.conv4 = nn.Conv2d(128, 128, 3, padding = 1)
        self.conv5 = nn.Conv2d(128, 256, 5, padding = 2)
        self.fc1 = nn.Linear(256 * 5 * 5, 1024)
        self.fc2 = nn.Linear(1024, 20)
    def forward(self, x):
        if torch.cuda.is_available():
            x = x.cuda()
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(F.relu(self.conv5(x)), 2)
        x = x.view(-1, 256 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training = self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim = 1)

# %%
model = Minist_two_Module()
if torch.cuda.is_available():
    model.cuda()

# %%
optimizer = optim.Adam(model.parameters(), lr = 0.001)
train_loss = []
train_accu = []
for epoch in range(20):
    for data, target in zip(batch_img, batch_label):
        data, target = Variable(data), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        optimizer.zero_grad()
        output = model(data)
        output1, output2 = torch.chunk(output, 2, dim = 1)
        target1, target2 = torch.chunk(target, 2, dim = 1)
        target1 = torch.squeeze(target1)
        target2 = torch.squeeze(target2)
        loss1 = F.nll_loss(output1, target1)
        loss2 = F.nll_loss(output2, target2)
        loss = (loss1 + loss2)/2
        loss.backward()
        train_loss.append(loss.data[0])
        optimizer.step()
        prediction1 = output1.data.max(1)[1]
        prediction2 = output2.data.max(1)[1]
        accurancy = ((prediction1.eq(target1.data).sum() + prediction2.eq(target2.data).sum()))/(2 * batch_size) * 100
        train_accu.append(accurancy)
        if i % 160 == 0:
            print('Train Step: {}\tLoss: {:.3f}\tAccuracy: {:.3f}'.format(i, loss.data[0], accurancy))
        i += 1
# Out:
# Train Step: 800	Loss: 2.985	Accuracy: 20.000
# Train Step: 960	Loss: 2.986	Accuracy: 19.000
# Train Step: 1120	Loss: 2.989	Accuracy: 19.000
# Train Step: 1280	Loss: 2.986	Accuracy: 19.000
# Train Step: 1440	Loss: 2.985	Accuracy: 19.000
# Train Step: 1600	Loss: 2.985	Accuracy: 19.000
# Train Step: 1760	Loss: 2.988	Accuracy: 19.000
# Train Step: 1920	Loss: 2.984	Accuracy: 19.000
# Train Step: 2080	Loss: 2.984	Accuracy: 19.000
# Train Step: 2240	Loss: 2.985	Accuracy: 19.000

# %%
model.eval()
correct = 0
test_img = torch.stack(test_img[ :len(test_img)], 0)
test_label = torch.stack(test_label[:len(test_label)], 0)
output = model(test_img)
prediction = output.data.max(1)[1]
correct += prediction.eq(test_label.data).sum()
print('\nTest set: Accuracy: {:.2f}%'.format(100 * correct/len(test_loader.dataset)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-3a30b162fae3> in <module>()
#       3 test_img = torch.stack(test_img[ :len(test_img)], 0)
#       4 test_label = torch.stack(test_label[:len(test_label)], 0)
# ----> 5 output = model(test_img)
#       6 prediction = output.data.max(1)[1]
#       7 correct += prediction.eq(test_label.data).sum()
#
# /usr/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# <ipython-input-27-7473a8d3b293> in forward(self, x)
#      12         if torch.cuda.is_available():
#      13             x = x.cuda()
# ---> 14         x = F.max_pool2d(F.relu(self.conv1(x)), 2)
#      15         x = F.max_pool2d(F.relu(self.conv2(x)), 2)
#      16         x = F.max_pool2d(F.relu(self.conv3(x)), 2)
#
# /usr/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     323         for hook in self._forward_pre_hooks.values():
#     324             hook(self, input)
# --> 325         result = self.forward(*input, **kwargs)
#     326         for hook in self._forward_hooks.values():
#     327             hook_result = hook(self, input, result)
#
# /usr/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     275     def forward(self, input):
#     276         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 277                         self.padding, self.dilation, self.groups)
#     278
#     279
#
# /usr/lib/python3.6/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# RuntimeError: cuda runtime error (2) : out of memory at /build/python-pytorch/src/pytorch-0.3.0-py3-cuda/torch/lib/THC/generic/THCStorage.cu:58
